# %%
#Import dependencies
import pandas as pd

# %%
#Read the weather_data.csv file
weather_path = "weather_data.csv"

#Create a dataframe from the weather_data.csv file
weather_df = pd.read_csv(weather_path)

#Print weather_df dataframe
weather_df.head()
# Out:
#    City ID    City  Latitude  Longitude  Max Temperature  Humidity  \
# 0        1  Kikwit     -5.04      18.82            74.84        85
# 1        2  Guilin     25.28     110.29            71.60        94
# 2        3  Hobart    -42.88     147.33            48.00        79
# 3        4  Albany     42.60     -73.97            64.99        95
# 4        5    Naze     28.37     129.48            80.60        94
#
#    Cloudiness  Wind Speed Country   Timestamp
# 0         100        0.67      CD  1598559844
# 1           0        1.59      CN  1598559781
# 2          90       10.29      AU  1598559463
# 3         100        4.79      US  1598559338
# 4          97        5.82      JP  1598559601

# %%
#Export the weather_df dataframe to html
    #https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.to_html.html
weather_df.to_csv('weather_data.html', index = False, header = True)
